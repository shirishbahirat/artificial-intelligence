# %% [markdown]
# <a href="https://colab.research.google.com/github/shirishbahirat/artificial-intelligence/blob/master/qlearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import numpy as np
from keras.models import Sequential
from keras.layers.core import Dense
from keras.optimizers import sgd


class Catch(object):
    def __init__(self, grid_size=10):
        self.grid_size = grid_size
        self.reset()

    def _update_state(self, action):
        """
        Input: action and states
        Ouput: new states and reward
        """
        state = self.state
        if action == 0:  # left
            action = -1
        elif action == 1:  # stay
            action = 0
        else:
            action = 1  # right
        f0, f1, basket = state[0]
        new_basket = min(max(1, basket + action), self.grid_size-1)
        f0 += 1
        out = np.asarray([f0, f1, new_basket])
        out = out[np.newaxis]

        assert len(out.shape) == 2
        self.state = out

    def _draw_state(self):
        im_size = (self.grid_size,)*2
        state = self.state[0]
        canvas = np.zeros(im_size)
        canvas[state[0], state[1]] = 1  # draw fruit
        canvas[-1, state[2]-1:state[2] + 2] = 1  # draw basket
        return canvas

    def _get_reward(self):
        fruit_row, fruit_col, basket = self.state[0]
        if fruit_row == self.grid_size-1:
            if abs(fruit_col - basket) <= 1:
                return 1
            else:
                return -1
        else:
            return 0

    def _is_over(self):
        if self.state[0, 0] == self.grid_size-1:
            return True
        else:
            return False

    def observe(self):
        canvas = self._draw_state()
        return canvas.reshape((1, -1))

    def act(self, action):
        self._update_state(action)
        reward = self._get_reward()
        game_over = self._is_over()
        return self.observe(), reward, game_over

    def reset(self):
        n = np.random.randint(0, self.grid_size-1, size=1)
        m = np.random.randint(1, self.grid_size-2, size=1)
        self.state = np.asarray([0, n, m])[np.newaxis]


class ExperienceReplay(object):
    def __init__(self, max_memory=100, discount=.9):
        self.max_memory = max_memory
        self.memory = list()
        self.discount = discount

    def remember(self, states, game_over):
        # memory[i] = [[state_t, action_t, reward_t, state_t+1], game_over?]
        self.memory.append([states, game_over])
        if len(self.memory) > self.max_memory:
            del self.memory[0]

    def get_batch(self, model, batch_size=10):
        len_memory = len(self.memory)
        num_actions = model.output_shape[-1]
        env_dim = self.memory[0][0][0].shape[1]
        inputs = np.zeros((min(len_memory, batch_size), env_dim))
        targets = np.zeros((inputs.shape[0], num_actions))
        for i, idx in enumerate(np.random.randint(0, len_memory,
                                                  size=inputs.shape[0])):
            state_t, action_t, reward_t, state_tp1 = self.memory[idx][0]
            game_over = self.memory[idx][1]

            inputs[i:i+1] = state_t
            # There should be no target values for actions not taken.
            # Thou shalt not correct actions not taken #deep
            targets[i] = model.predict(state_t)[0]
            Q_sa = np.max(model.predict(state_tp1)[0])
            if game_over:  # if game_over is True
                targets[i, action_t] = reward_t
            else:
                # reward_t + gamma * max_a' Q(s', a')
                targets[i, action_t] = reward_t + self.discount * Q_sa
        return inputs, targets


if __name__ == "__main__":
    # parameters
    epsilon = .1  # exploration
    num_actions = 3  # [move_left, stay, move_right]
    epoch = 1000
    max_memory = 500
    hidden_size = 100
    batch_size = 50
    grid_size = 10

    model = Sequential()
    model.add(Dense(hidden_size, input_shape=(grid_size**2,), activation='relu'))
    model.add(Dense(hidden_size, activation='relu'))
    model.add(Dense(num_actions))
    model.compile(sgd(lr=.2), "mse")

    # If you want to continue training from a previous model, just uncomment the line bellow
    # model.load_weights("model.h5")

    # Define environment/game
    env = Catch(grid_size)

    # Initialize experience replay object
    exp_replay = ExperienceReplay(max_memory=max_memory)

    # Train
    win_cnt = 0
    for e in range(epoch):
        loss = 0.
        env.reset()
        game_over = False
        # get initial input
        input_t = env.observe()

        while not game_over:
            input_tm1 = input_t
            # get next action
            if np.random.rand() <= epsilon:
                action = np.random.randint(0, num_actions, size=1)
            else:
                q = model.predict(input_tm1)
                action = np.argmax(q[0])

            # apply action, get rewards and new state
            input_t, reward, game_over = env.act(action)
            if reward == 1:
                win_cnt += 1

            # store experience
            exp_replay.remember([input_tm1, action, reward, input_t], game_over)

            # adapt model
            inputs, targets = exp_replay.get_batch(model, batch_size=batch_size)

            loss += model.train_on_batch(inputs, targets)
        print("Epoch {:03d}/999 | Loss {:.4f} | Win count {}".format(e, loss, win_cnt))

    # Save trained model weights and architecture, this will be used by the visualization code
    model.save_weights("model.h5", overwrite=True)
    with open("model.json", "w") as outfile:
        json.dump(model.to_json(), outfile)
# Out:
# Epoch 000/999 | Loss 0.0119 | Win count 0
# Epoch 001/999 | Loss 0.2911 | Win count 0
# Epoch 002/999 | Loss 0.1647 | Win count 0
# Epoch 003/999 | Loss 0.2423 | Win count 0
# Epoch 004/999 | Loss 0.1942 | Win count 0
# Epoch 005/999 | Loss 0.1580 | Win count 0
# Epoch 006/999 | Loss 0.1299 | Win count 0
# Epoch 007/999 | Loss 0.1417 | Win count 1
# Epoch 008/999 | Loss 0.1389 | Win count 1
# Epoch 009/999 | Loss 0.1549 | Win count 2
# Epoch 010/999 | Loss 0.1861 | Win count 2
# Epoch 011/999 | Loss 0.2214 | Win count 3
# Epoch 012/999 | Loss 0.2343 | Win count 3
# Epoch 013/999 | Loss 0.2398 | Win count 4
# Epoch 014/999 | Loss 0.1886 | Win count 4
# Epoch 015/999 | Loss 0.1822 | Win count 5
# Epoch 016/999 | Loss 0.2144 | Win count 6
# Epoch 017/999 | Loss 0.2417 | Win count 6
# Epoch 018/999 | Loss 0.1834 | Win count 6
# Epoch 019/999 | Loss 0.2335 | Win count 7
# Epoch 020/999 | Loss 0.1767 | Win count 7
# Epoch 021/999 | Loss 0.2227 | Win count 8
# Epoch 022/999 | Loss 0.2137 | Win count 8
# Epoch 023/999 | Loss 0.2294 | Win count 8
# Epoch 024/999 | Loss 0.2204 | Win count 8
# Epoch 025/999 | Loss 0.2214 | Win count 9
# Epoch 026/999 | Loss 0.2263 | Win count 9
# Epoch 027/999 | Loss 0.2532 | Win count 9
# Epoch 028/999 | Loss 0.2441 | Win count 9
# Epoch 029/999 | Loss 0.2017 | Win count 9
# Epoch 030/999 | Loss 0.1777 | Win count 10
# Epoch 031/999 | Loss 0.2086 | Win count 10
# Epoch 032/999 | Loss 0.2492 | Win count 11
# Epoch 033/999 | Loss 0.1368 | Win count 11
# Epoch 034/999 | Loss 0.1973 | Win count 11
# Epoch 035/999 | Loss 0.2167 | Win count 11
# Epoch 036/999 | Loss 0.1583 | Win count 11
# Epoch 037/999 | Loss 0.2261 | Win count 11
# Epoch 038/999 | Loss 0.2496 | Win count 11
# Epoch 039/999 | Loss 0.1987 | Win count 12
# Epoch 040/999 | Loss 0.1890 | Win count 12
# Epoch 041/999 | Loss 0.1991 | Win count 13
# Epoch 042/999 | Loss 0.1915 | Win count 13
# Epoch 043/999 | Loss 0.1966 | Win count 13
# Epoch 044/999 | Loss 0.1652 | Win count 13
# Epoch 045/999 | Loss 0.1902 | Win count 13
# Epoch 046/999 | Loss 0.1887 | Win count 13
# Epoch 047/999 | Loss 0.1992 | Win count 13
# Epoch 048/999 | Loss 0.1806 | Win count 13
# Epoch 049/999 | Loss 0.1593 | Win count 13
# Epoch 050/999 | Loss 0.1570 | Win count 14
# Epoch 051/999 | Loss 0.1759 | Win count 15
# Epoch 052/999 | Loss 0.1554 | Win count 16
# Epoch 053/999 | Loss 0.1620 | Win count 17
# Epoch 054/999 | Loss 0.1628 | Win count 17
# Epoch 055/999 | Loss 0.1668 | Win count 17
# Epoch 056/999 | Loss 0.1377 | Win count 18
# Epoch 057/999 | Loss 0.1975 | Win count 18
# Epoch 058/999 | Loss 0.1848 | Win count 19
# Epoch 059/999 | Loss 0.1752 | Win count 20
# Epoch 060/999 | Loss 0.1407 | Win count 21
# Epoch 061/999 | Loss 0.1371 | Win count 21
# Epoch 062/999 | Loss 0.1420 | Win count 21
# Epoch 063/999 | Loss 0.1676 | Win count 22
# Epoch 064/999 | Loss 0.1807 | Win count 23
# Epoch 065/999 | Loss 0.1655 | Win count 23
# Epoch 066/999 | Loss 0.1902 | Win count 24
# Epoch 067/999 | Loss 0.1737 | Win count 25
# Epoch 068/999 | Loss 0.1725 | Win count 25
# Epoch 069/999 | Loss 0.1721 | Win count 25
# Epoch 070/999 | Loss 0.1553 | Win count 26
# Epoch 071/999 | Loss 0.1896 | Win count 27
# Epoch 072/999 | Loss 0.2072 | Win count 27
# Epoch 073/999 | Loss 0.1581 | Win count 28
# Epoch 074/999 | Loss 0.2149 | Win count 28
# Epoch 075/999 | Loss 0.1317 | Win count 28
# Epoch 076/999 | Loss 0.1264 | Win count 28
# Epoch 077/999 | Loss 0.1677 | Win count 28
# Epoch 078/999 | Loss 0.1729 | Win count 28
# Epoch 079/999 | Loss 0.1400 | Win count 28
# Epoch 080/999 | Loss 0.2343 | Win count 29
# Epoch 081/999 | Loss 0.1127 | Win count 30
# Epoch 082/999 | Loss 0.2141 | Win count 31
# Epoch 083/999 | Loss 0.1462 | Win count 31
# Epoch 084/999 | Loss 0.1261 | Win count 32
# Epoch 085/999 | Loss 0.1587 | Win count 32
# Epoch 086/999 | Loss 0.1082 | Win count 32
# Epoch 087/999 | Loss 0.1796 | Win count 32
# Epoch 088/999 | Loss 0.1349 | Win count 33
# Epoch 089/999 | Loss 0.1406 | Win count 34
# Epoch 090/999 | Loss 0.1503 | Win count 34
# Epoch 091/999 | Loss 0.1565 | Win count 34
# Epoch 092/999 | Loss 0.1174 | Win count 35
# Epoch 093/999 | Loss 0.1407 | Win count 35
# Epoch 094/999 | Loss 0.1407 | Win count 36
# Epoch 095/999 | Loss 0.1460 | Win count 37
# Epoch 096/999 | Loss 0.1621 | Win count 38
# Epoch 097/999 | Loss 0.1316 | Win count 38
# Epoch 098/999 | Loss 0.1157 | Win count 38
# Epoch 099/999 | Loss 0.1267 | Win count 39
# Epoch 100/999 | Loss 0.1486 | Win count 39
# Epoch 101/999 | Loss 0.1167 | Win count 40
# Epoch 102/999 | Loss 0.1415 | Win count 41
# Epoch 103/999 | Loss 0.1383 | Win count 41
# Epoch 104/999 | Loss 0.1933 | Win count 42
# Epoch 105/999 | Loss 0.1676 | Win count 43
# Epoch 106/999 | Loss 0.1635 | Win count 43
# Epoch 107/999 | Loss 0.1633 | Win count 44
# Epoch 108/999 | Loss 0.1572 | Win count 45
# Epoch 109/999 | Loss 0.1663 | Win count 45
# Epoch 110/999 | Loss 0.1472 | Win count 45
# Epoch 111/999 | Loss 0.1655 | Win count 46
# Epoch 112/999 | Loss 0.1502 | Win count 47
# Epoch 113/999 | Loss 0.1661 | Win count 48
# Epoch 114/999 | Loss 0.1652 | Win count 49
# Epoch 115/999 | Loss 0.1435 | Win count 49
# Epoch 116/999 | Loss 0.1573 | Win count 50
# Epoch 117/999 | Loss 0.1902 | Win count 51
# Epoch 118/999 | Loss 0.1636 | Win count 51
# Epoch 119/999 | Loss 0.1978 | Win count 52
# Epoch 120/999 | Loss 0.1408 | Win count 53
# Epoch 121/999 | Loss 0.1247 | Win count 54
# Epoch 122/999 | Loss 0.1535 | Win count 55
# Epoch 123/999 | Loss 0.1607 | Win count 55
# Epoch 124/999 | Loss 0.1813 | Win count 55
# Epoch 125/999 | Loss 0.1685 | Win count 55
# Epoch 126/999 | Loss 0.1958 | Win count 56
# Epoch 127/999 | Loss 0.1980 | Win count 56
# Epoch 128/999 | Loss 0.1783 | Win count 56
# Epoch 129/999 | Loss 0.2286 | Win count 57
# Epoch 130/999 | Loss 0.1554 | Win count 57
# Epoch 131/999 | Loss 0.1755 | Win count 58
# Epoch 132/999 | Loss 0.1717 | Win count 59
# Epoch 133/999 | Loss 0.1577 | Win count 60
# Epoch 134/999 | Loss 0.1423 | Win count 60
# Epoch 135/999 | Loss 0.2465 | Win count 61
# Epoch 136/999 | Loss 0.1461 | Win count 62
# Epoch 137/999 | Loss 0.1724 | Win count 63
# Epoch 138/999 | Loss 0.1798 | Win count 64
# Epoch 139/999 | Loss 0.1699 | Win count 65
# Epoch 140/999 | Loss 0.1918 | Win count 66
# Epoch 141/999 | Loss 0.1986 | Win count 67
# Epoch 142/999 | Loss 0.1710 | Win count 68
# Epoch 143/999 | Loss 0.1654 | Win count 69
# Epoch 144/999 | Loss 0.1731 | Win count 69
# Epoch 145/999 | Loss 0.1489 | Win count 70
# Epoch 146/999 | Loss 0.1893 | Win count 71
# Epoch 147/999 | Loss 0.1616 | Win count 72
# Epoch 148/999 | Loss 0.1185 | Win count 73
# Epoch 149/999 | Loss 0.1138 | Win count 74
# Epoch 150/999 | Loss 0.1258 | Win count 74
# Epoch 151/999 | Loss 0.1622 | Win count 74
# Epoch 152/999 | Loss 0.1627 | Win count 75
# Epoch 153/999 | Loss 0.1517 | Win count 76
# Epoch 154/999 | Loss 0.1294 | Win count 77
# Epoch 155/999 | Loss 0.1110 | Win count 78
# Epoch 156/999 | Loss 0.1767 | Win count 78
# Epoch 157/999 | Loss 0.1479 | Win count 79
# Epoch 158/999 | Loss 0.1698 | Win count 80
# Epoch 159/999 | Loss 0.1195 | Win count 80
# Epoch 160/999 | Loss 0.1618 | Win count 80
# Epoch 161/999 | Loss 0.1677 | Win count 80
# Epoch 162/999 | Loss 0.1480 | Win count 80
# Epoch 163/999 | Loss 0.1409 | Win count 80
# Epoch 164/999 | Loss 0.1481 | Win count 80
# Epoch 165/999 | Loss 0.1691 | Win count 81
# Epoch 166/999 | Loss 0.0979 | Win count 82
# Epoch 167/999 | Loss 0.1937 | Win count 83
# Epoch 168/999 | Loss 0.1317 | Win count 83
# Epoch 169/999 | Loss 0.1398 | Win count 83
# Epoch 170/999 | Loss 0.1475 | Win count 83
# Epoch 171/999 | Loss 0.1699 | Win count 84
# Epoch 172/999 | Loss 0.1501 | Win count 84
# Epoch 173/999 | Loss 0.1082 | Win count 84
# Epoch 174/999 | Loss 0.1165 | Win count 85
# Epoch 175/999 | Loss 0.1614 | Win count 86
# Epoch 176/999 | Loss 0.1190 | Win count 86
# Epoch 177/999 | Loss 0.1195 | Win count 86
# Epoch 178/999 | Loss 0.1488 | Win count 87
# Epoch 179/999 | Loss 0.1488 | Win count 88
# Epoch 180/999 | Loss 0.1216 | Win count 89
# Epoch 181/999 | Loss 0.1392 | Win count 90
# Epoch 182/999 | Loss 0.1439 | Win count 91
# Epoch 183/999 | Loss 0.1253 | Win count 92
# Epoch 184/999 | Loss 0.1317 | Win count 93
# Epoch 185/999 | Loss 0.1474 | Win count 94
# Epoch 186/999 | Loss 0.1117 | Win count 95
# Epoch 187/999 | Loss 0.1113 | Win count 95
# Epoch 188/999 | Loss 0.0993 | Win count 95
# Epoch 189/999 | Loss 0.1256 | Win count 96
# Epoch 190/999 | Loss 0.0978 | Win count 96
# Epoch 191/999 | Loss 0.1081 | Win count 96
# Epoch 192/999 | Loss 0.0836 | Win count 97
# Epoch 193/999 | Loss 0.1110 | Win count 98
# Epoch 194/999 | Loss 0.1287 | Win count 99
# Epoch 195/999 | Loss 0.1067 | Win count 99
# Epoch 196/999 | Loss 0.1144 | Win count 99
# Epoch 197/999 | Loss 0.1067 | Win count 100
# Epoch 198/999 | Loss 0.0935 | Win count 101
# Epoch 199/999 | Loss 0.1081 | Win count 101
# Epoch 200/999 | Loss 0.0935 | Win count 101
# Epoch 201/999 | Loss 0.0989 | Win count 101
# Epoch 202/999 | Loss 0.1029 | Win count 102
# Epoch 203/999 | Loss 0.1112 | Win count 102
# Epoch 204/999 | Loss 0.1008 | Win count 103
# Epoch 205/999 | Loss 0.1108 | Win count 103
# Epoch 206/999 | Loss 0.1256 | Win count 104
# Epoch 207/999 | Loss 0.1306 | Win count 105
# Epoch 208/999 | Loss 0.1156 | Win count 105
# Epoch 209/999 | Loss 0.1110 | Win count 105
# Epoch 210/999 | Loss 0.1017 | Win count 106
# Epoch 211/999 | Loss 0.0855 | Win count 107
# Epoch 212/999 | Loss 0.0748 | Win count 107
# Epoch 213/999 | Loss 0.1034 | Win count 108
# Epoch 214/999 | Loss 0.1003 | Win count 109
# Epoch 215/999 | Loss 0.0810 | Win count 110
# Epoch 216/999 | Loss 0.1326 | Win count 111
# Epoch 217/999 | Loss 0.1015 | Win count 112
# Epoch 218/999 | Loss 0.0854 | Win count 112
# Epoch 219/999 | Loss 0.0951 | Win count 113
# Epoch 220/999 | Loss 0.0879 | Win count 114
# Epoch 221/999 | Loss 0.1173 | Win count 114
# Epoch 222/999 | Loss 0.0881 | Win count 114
# Epoch 223/999 | Loss 0.1200 | Win count 115
# Epoch 224/999 | Loss 0.1347 | Win count 116
# Epoch 225/999 | Loss 0.1188 | Win count 117
# Epoch 226/999 | Loss 0.1315 | Win count 118
# Epoch 227/999 | Loss 0.1043 | Win count 118
# Epoch 228/999 | Loss 0.1313 | Win count 118
# Epoch 229/999 | Loss 0.1319 | Win count 119
# Epoch 230/999 | Loss 0.1248 | Win count 120
# Epoch 231/999 | Loss 0.1351 | Win count 120
# Epoch 232/999 | Loss 0.1268 | Win count 120
# Epoch 233/999 | Loss 0.0596 | Win count 120
# Epoch 234/999 | Loss 0.1158 | Win count 121
# Epoch 235/999 | Loss 0.0974 | Win count 122
# Epoch 236/999 | Loss 0.0814 | Win count 122
# Epoch 237/999 | Loss 0.0890 | Win count 123
# Epoch 238/999 | Loss 0.0960 | Win count 123
# Epoch 239/999 | Loss 0.0843 | Win count 124
# Epoch 240/999 | Loss 0.1322 | Win count 125
# Epoch 241/999 | Loss 0.0925 | Win count 126
# Epoch 242/999 | Loss 0.1027 | Win count 126
# Epoch 243/999 | Loss 0.0809 | Win count 126
# Epoch 244/999 | Loss 0.0887 | Win count 126
# Epoch 245/999 | Loss 0.0999 | Win count 126
# Epoch 246/999 | Loss 0.0691 | Win count 127
# Epoch 247/999 | Loss 0.0971 | Win count 128
# Epoch 248/999 | Loss 0.0845 | Win count 129
# Epoch 249/999 | Loss 0.0874 | Win count 130
# Epoch 250/999 | Loss 0.1222 | Win count 131
# Epoch 251/999 | Loss 0.0979 | Win count 132
# Epoch 252/999 | Loss 0.0959 | Win count 132
# Epoch 253/999 | Loss 0.0682 | Win count 133
# Epoch 254/999 | Loss 0.0734 | Win count 133
# Epoch 255/999 | Loss 0.1155 | Win count 134
# Epoch 256/999 | Loss 0.0771 | Win count 135
# Epoch 257/999 | Loss 0.0722 | Win count 135
# Epoch 258/999 | Loss 0.0920 | Win count 135
# Epoch 259/999 | Loss 0.0730 | Win count 136
# Epoch 260/999 | Loss 0.0800 | Win count 137
# Epoch 261/999 | Loss 0.1117 | Win count 138
# Epoch 262/999 | Loss 0.1083 | Win count 139
# Epoch 263/999 | Loss 0.0695 | Win count 140
# Epoch 264/999 | Loss 0.0966 | Win count 141
# Epoch 265/999 | Loss 0.0813 | Win count 141
# Epoch 266/999 | Loss 0.0882 | Win count 142
# Epoch 267/999 | Loss 0.0661 | Win count 143
# Epoch 268/999 | Loss 0.0808 | Win count 144
# Epoch 269/999 | Loss 0.0835 | Win count 145
# Epoch 270/999 | Loss 0.0721 | Win count 146
# Epoch 271/999 | Loss 0.0881 | Win count 146
# Epoch 272/999 | Loss 0.0682 | Win count 147
# Epoch 273/999 | Loss 0.0554 | Win count 148
# Epoch 274/999 | Loss 0.0606 | Win count 148
# Epoch 275/999 | Loss 0.0519 | Win count 149
# Epoch 276/999 | Loss 0.0563 | Win count 150
# Epoch 277/999 | Loss 0.0620 | Win count 150
# Epoch 278/999 | Loss 0.0567 | Win count 150
# Epoch 279/999 | Loss 0.0653 | Win count 151
# Epoch 280/999 | Loss 0.0521 | Win count 152
# Epoch 281/999 | Loss 0.0566 | Win count 153
# Epoch 282/999 | Loss 0.0550 | Win count 154
# Epoch 283/999 | Loss 0.0427 | Win count 155
# Epoch 284/999 | Loss 0.0478 | Win count 156
# Epoch 285/999 | Loss 0.0385 | Win count 157
# Epoch 286/999 | Loss 0.0436 | Win count 158
# Epoch 287/999 | Loss 0.0304 | Win count 159
# Epoch 288/999 | Loss 0.0456 | Win count 160
# Epoch 289/999 | Loss 0.0612 | Win count 160
# Epoch 290/999 | Loss 0.0427 | Win count 161
# Epoch 291/999 | Loss 0.0476 | Win count 161
# Epoch 292/999 | Loss 0.0469 | Win count 162
# Epoch 293/999 | Loss 0.0316 | Win count 162
# Epoch 294/999 | Loss 0.0537 | Win count 163
# Epoch 295/999 | Loss 0.0436 | Win count 164
# Epoch 296/999 | Loss 0.0625 | Win count 165
# Epoch 297/999 | Loss 0.0883 | Win count 166
# Epoch 298/999 | Loss 0.0657 | Win count 167
# Epoch 299/999 | Loss 0.0425 | Win count 168
# Epoch 300/999 | Loss 0.0648 | Win count 169
# Epoch 301/999 | Loss 0.0530 | Win count 170
# Epoch 302/999 | Loss 0.0508 | Win count 171
# Epoch 303/999 | Loss 0.0302 | Win count 171
# Epoch 304/999 | Loss 0.0332 | Win count 172
# Epoch 305/999 | Loss 0.0392 | Win count 173
# Epoch 306/999 | Loss 0.0402 | Win count 174
# Epoch 307/999 | Loss 0.0521 | Win count 174
# Epoch 308/999 | Loss 0.0634 | Win count 174
# Epoch 309/999 | Loss 0.0401 | Win count 175
# Epoch 310/999 | Loss 0.0472 | Win count 176
# Epoch 311/999 | Loss 0.0747 | Win count 177
# Epoch 312/999 | Loss 0.0587 | Win count 178
# Epoch 313/999 | Loss 0.0548 | Win count 178
# Epoch 314/999 | Loss 0.0731 | Win count 179
# Epoch 315/999 | Loss 0.0380 | Win count 180
# Epoch 316/999 | Loss 0.0435 | Win count 181
# Epoch 317/999 | Loss 0.0503 | Win count 182
# Epoch 318/999 | Loss 0.0403 | Win count 182
# Epoch 319/999 | Loss 0.0475 | Win count 183
# Epoch 320/999 | Loss 0.0593 | Win count 184
# Epoch 321/999 | Loss 0.0512 | Win count 184
# Epoch 322/999 | Loss 0.0383 | Win count 185
# Epoch 323/999 | Loss 0.0434 | Win count 186
# Epoch 324/999 | Loss 0.0346 | Win count 186
# Epoch 325/999 | Loss 0.0320 | Win count 187
# Epoch 326/999 | Loss 0.0331 | Win count 188
# Epoch 327/999 | Loss 0.0459 | Win count 188
# Epoch 328/999 | Loss 0.0375 | Win count 189
# Epoch 329/999 | Loss 0.0339 | Win count 190
# Epoch 330/999 | Loss 0.0514 | Win count 191
# Epoch 331/999 | Loss 0.0429 | Win count 192
# Epoch 332/999 | Loss 0.0389 | Win count 193
# Epoch 333/999 | Loss 0.0337 | Win count 193
# Epoch 334/999 | Loss 0.0436 | Win count 194
# Epoch 335/999 | Loss 0.0425 | Win count 195
# Epoch 336/999 | Loss 0.0436 | Win count 196
# Epoch 337/999 | Loss 0.0332 | Win count 197
# Epoch 338/999 | Loss 0.0411 | Win count 198
# Epoch 339/999 | Loss 0.0347 | Win count 199
# Epoch 340/999 | Loss 0.0352 | Win count 200
# Epoch 341/999 | Loss 0.0349 | Win count 201
# Epoch 342/999 | Loss 0.0348 | Win count 202
# Epoch 343/999 | Loss 0.0287 | Win count 203
# Epoch 344/999 | Loss 0.0218 | Win count 204
# Epoch 345/999 | Loss 0.0314 | Win count 204
# Epoch 346/999 | Loss 0.0247 | Win count 205
# Epoch 347/999 | Loss 0.0294 | Win count 206
# Epoch 348/999 | Loss 0.0311 | Win count 206
# Epoch 349/999 | Loss 0.0435 | Win count 207
# Epoch 350/999 | Loss 0.0266 | Win count 208
# Epoch 351/999 | Loss 0.0232 | Win count 208
# Epoch 352/999 | Loss 0.0475 | Win count 209
# Epoch 353/999 | Loss 0.0318 | Win count 210
# Epoch 354/999 | Loss 0.0502 | Win count 211
# Epoch 355/999 | Loss 0.0427 | Win count 212
# Epoch 356/999 | Loss 0.0802 | Win count 213
# Epoch 357/999 | Loss 0.0446 | Win count 214
# Epoch 358/999 | Loss 0.0408 | Win count 215
# Epoch 359/999 | Loss 0.0450 | Win count 216
# Epoch 360/999 | Loss 0.0411 | Win count 217
# Epoch 361/999 | Loss 0.0549 | Win count 218
# Epoch 362/999 | Loss 0.0414 | Win count 219
# Epoch 363/999 | Loss 0.0411 | Win count 220
# Epoch 364/999 | Loss 0.0320 | Win count 221
# Epoch 365/999 | Loss 0.0366 | Win count 222
# Epoch 366/999 | Loss 0.0495 | Win count 223
# Epoch 367/999 | Loss 0.0402 | Win count 224
# Epoch 368/999 | Loss 0.0497 | Win count 225
# Epoch 369/999 | Loss 0.0320 | Win count 226
# Epoch 370/999 | Loss 0.0334 | Win count 227
# Epoch 371/999 | Loss 0.0337 | Win count 227
# Epoch 372/999 | Loss 0.0508 | Win count 228
# Epoch 373/999 | Loss 0.0289 | Win count 229
# Epoch 374/999 | Loss 0.0533 | Win count 230
# Epoch 375/999 | Loss 0.0422 | Win count 231
# Epoch 376/999 | Loss 0.0279 | Win count 232
# Epoch 377/999 | Loss 0.0477 | Win count 233
# Epoch 378/999 | Loss 0.0277 | Win count 234
# Epoch 379/999 | Loss 0.0430 | Win count 235
# Epoch 380/999 | Loss 0.0243 | Win count 236
# Epoch 381/999 | Loss 0.0475 | Win count 237
# Epoch 382/999 | Loss 0.0304 | Win count 238
# Epoch 383/999 | Loss 0.0360 | Win count 239
# Epoch 384/999 | Loss 0.0463 | Win count 240
# Epoch 385/999 | Loss 0.0270 | Win count 241
# Epoch 386/999 | Loss 0.0486 | Win count 242
# Epoch 387/999 | Loss 0.0308 | Win count 243
# Epoch 388/999 | Loss 0.0668 | Win count 243
# Epoch 389/999 | Loss 0.0399 | Win count 244
# Epoch 390/999 | Loss 0.0323 | Win count 245
# Epoch 391/999 | Loss 0.0415 | Win count 245
# Epoch 392/999 | Loss 0.0510 | Win count 246
# Epoch 393/999 | Loss 0.0413 | Win count 247
# Epoch 394/999 | Loss 0.0527 | Win count 248
# Epoch 395/999 | Loss 0.0351 | Win count 249
# Epoch 396/999 | Loss 0.0410 | Win count 250
# Epoch 397/999 | Loss 0.0331 | Win count 251
# Epoch 398/999 | Loss 0.0369 | Win count 252
# Epoch 399/999 | Loss 0.0389 | Win count 253
# Epoch 400/999 | Loss 0.0383 | Win count 254
# Epoch 401/999 | Loss 0.0269 | Win count 255
# Epoch 402/999 | Loss 0.0263 | Win count 256
# Epoch 403/999 | Loss 0.0281 | Win count 257
# Epoch 404/999 | Loss 0.0310 | Win count 258
# Epoch 405/999 | Loss 0.0347 | Win count 258
# Epoch 406/999 | Loss 0.0360 | Win count 259
# Epoch 407/999 | Loss 0.0346 | Win count 260
# Epoch 408/999 | Loss 0.0391 | Win count 261
# Epoch 409/999 | Loss 0.0409 | Win count 261
# Epoch 410/999 | Loss 0.0352 | Win count 262
# Epoch 411/999 | Loss 0.0444 | Win count 262
# Epoch 412/999 | Loss 0.0597 | Win count 263
# Epoch 413/999 | Loss 0.0406 | Win count 264
# Epoch 414/999 | Loss 0.0499 | Win count 265
# Epoch 415/999 | Loss 0.0434 | Win count 266
# Epoch 416/999 | Loss 0.0239 | Win count 267
# Epoch 417/999 | Loss 0.0478 | Win count 268
# Epoch 418/999 | Loss 0.0452 | Win count 269
# Epoch 419/999 | Loss 0.0401 | Win count 270
# Epoch 420/999 | Loss 0.0286 | Win count 271
# Epoch 421/999 | Loss 0.0185 | Win count 271
# Epoch 422/999 | Loss 0.0253 | Win count 272
# Epoch 423/999 | Loss 0.0264 | Win count 272
# Epoch 424/999 | Loss 0.0294 | Win count 273
# Epoch 425/999 | Loss 0.0281 | Win count 274
# Epoch 426/999 | Loss 0.0293 | Win count 275
# Epoch 427/999 | Loss 0.0353 | Win count 276
# Epoch 428/999 | Loss 0.0299 | Win count 277
# Epoch 429/999 | Loss 0.0406 | Win count 278
# Epoch 430/999 | Loss 0.0302 | Win count 279
# Epoch 431/999 | Loss 0.0573 | Win count 280
# Epoch 432/999 | Loss 0.0264 | Win count 281
# Epoch 433/999 | Loss 0.0614 | Win count 282
# Epoch 434/999 | Loss 0.0304 | Win count 283
# Epoch 435/999 | Loss 0.0221 | Win count 284
# Epoch 436/999 | Loss 0.0269 | Win count 284
# Epoch 437/999 | Loss 0.0430 | Win count 285
# Epoch 438/999 | Loss 0.0406 | Win count 286
# Epoch 439/999 | Loss 0.0367 | Win count 287
# Epoch 440/999 | Loss 0.0264 | Win count 288
# Epoch 441/999 | Loss 0.0262 | Win count 289
# Epoch 442/999 | Loss 0.0384 | Win count 290
# Epoch 443/999 | Loss 0.0270 | Win count 290
# Epoch 444/999 | Loss 0.0384 | Win count 291
# Epoch 445/999 | Loss 0.0274 | Win count 292
# Epoch 446/999 | Loss 0.0443 | Win count 293
# Epoch 447/999 | Loss 0.0228 | Win count 294
# Epoch 448/999 | Loss 0.0297 | Win count 295
# Epoch 449/999 | Loss 0.0292 | Win count 296
# Epoch 450/999 | Loss 0.0282 | Win count 297
# Epoch 451/999 | Loss 0.0196 | Win count 298
# Epoch 452/999 | Loss 0.0234 | Win count 299
# Epoch 453/999 | Loss 0.0174 | Win count 299
# Epoch 454/999 | Loss 0.0275 | Win count 300
# Epoch 455/999 | Loss 0.0301 | Win count 301
# Epoch 456/999 | Loss 0.0690 | Win count 302
# Epoch 457/999 | Loss 0.0491 | Win count 303
# Epoch 458/999 | Loss 0.0223 | Win count 304
# Epoch 459/999 | Loss 0.0447 | Win count 305
# Epoch 460/999 | Loss 0.0246 | Win count 306
# Epoch 461/999 | Loss 0.0372 | Win count 307
# Epoch 462/999 | Loss 0.0346 | Win count 308
# Epoch 463/999 | Loss 0.0375 | Win count 309
# Epoch 464/999 | Loss 0.0350 | Win count 310
# Epoch 465/999 | Loss 0.0185 | Win count 311
# Epoch 466/999 | Loss 0.0457 | Win count 312
# Epoch 467/999 | Loss 0.0213 | Win count 313
# Epoch 468/999 | Loss 0.0320 | Win count 314
# Epoch 469/999 | Loss 0.0277 | Win count 315
# Epoch 470/999 | Loss 0.0335 | Win count 316
# Epoch 471/999 | Loss 0.0189 | Win count 317
# Epoch 472/999 | Loss 0.0380 | Win count 318
# Epoch 473/999 | Loss 0.0198 | Win count 319
# Epoch 474/999 | Loss 0.0181 | Win count 320
# Epoch 475/999 | Loss 0.0339 | Win count 321
# Epoch 476/999 | Loss 0.0573 | Win count 322
# Epoch 477/999 | Loss 0.0169 | Win count 323
# Epoch 478/999 | Loss 0.0266 | Win count 324
# Epoch 479/999 | Loss 0.0380 | Win count 324
# Epoch 480/999 | Loss 0.0453 | Win count 325
# Epoch 481/999 | Loss 0.0288 | Win count 326
# Epoch 482/999 | Loss 0.0350 | Win count 327
# Epoch 483/999 | Loss 0.0232 | Win count 328
# Epoch 484/999 | Loss 0.0244 | Win count 329
# Epoch 485/999 | Loss 0.0174 | Win count 330
# Epoch 486/999 | Loss 0.0185 | Win count 331
# Epoch 487/999 | Loss 0.0165 | Win count 332
# Epoch 488/999 | Loss 0.0167 | Win count 333
# Epoch 489/999 | Loss 0.0209 | Win count 334
# Epoch 490/999 | Loss 0.0201 | Win count 335
# Epoch 491/999 | Loss 0.0143 | Win count 336
# Epoch 492/999 | Loss 0.0166 | Win count 337
# Epoch 493/999 | Loss 0.0228 | Win count 337
# Epoch 494/999 | Loss 0.0249 | Win count 338
# Epoch 495/999 | Loss 0.0132 | Win count 339
# Epoch 496/999 | Loss 0.0163 | Win count 340
# Epoch 497/999 | Loss 0.0170 | Win count 341
# Epoch 498/999 | Loss 0.0208 | Win count 342
# Epoch 499/999 | Loss 0.0279 | Win count 343
# Epoch 500/999 | Loss 0.0136 | Win count 344
# Epoch 501/999 | Loss 0.0169 | Win count 345
# Epoch 502/999 | Loss 0.0211 | Win count 346
# Epoch 503/999 | Loss 0.0137 | Win count 347
# Epoch 504/999 | Loss 0.0191 | Win count 348
# Epoch 505/999 | Loss 0.0189 | Win count 349
# Epoch 506/999 | Loss 0.0123 | Win count 350
# Epoch 507/999 | Loss 0.0121 | Win count 351
# Epoch 508/999 | Loss 0.0127 | Win count 352
# Epoch 509/999 | Loss 0.0215 | Win count 352
# Epoch 510/999 | Loss 0.0199 | Win count 353
# Epoch 511/999 | Loss 0.0203 | Win count 354
# Epoch 512/999 | Loss 0.0128 | Win count 355
# Epoch 513/999 | Loss 0.0208 | Win count 356
# Epoch 514/999 | Loss 0.0187 | Win count 357
# Epoch 515/999 | Loss 0.0173 | Win count 358
# Epoch 516/999 | Loss 0.0142 | Win count 359
# Epoch 517/999 | Loss 0.0152 | Win count 360
# Epoch 518/999 | Loss 0.0099 | Win count 361
# Epoch 519/999 | Loss 0.0158 | Win count 362
# Epoch 520/999 | Loss 0.0121 | Win count 363
# Epoch 521/999 | Loss 0.0148 | Win count 364
# Epoch 522/999 | Loss 0.0160 | Win count 365
# Epoch 523/999 | Loss 0.0120 | Win count 365
# Epoch 524/999 | Loss 0.0359 | Win count 365
# Epoch 525/999 | Loss 0.0127 | Win count 366
# Epoch 526/999 | Loss 0.0340 | Win count 367
# Epoch 527/999 | Loss 0.0310 | Win count 368
# Epoch 528/999 | Loss 0.0213 | Win count 369
# Epoch 529/999 | Loss 0.0171 | Win count 370
# Epoch 530/999 | Loss 0.0362 | Win count 371
# Epoch 531/999 | Loss 0.0222 | Win count 372
# Epoch 532/999 | Loss 0.0168 | Win count 373
# Epoch 533/999 | Loss 0.0310 | Win count 373
# Epoch 534/999 | Loss 0.0266 | Win count 374
# Epoch 535/999 | Loss 0.0288 | Win count 375
# Epoch 536/999 | Loss 0.0193 | Win count 376
# Epoch 537/999 | Loss 0.0396 | Win count 377
# Epoch 538/999 | Loss 0.0251 | Win count 378
# Epoch 539/999 | Loss 0.0250 | Win count 379
# Epoch 540/999 | Loss 0.0286 | Win count 380
# Epoch 541/999 | Loss 0.0109 | Win count 381
# Epoch 542/999 | Loss 0.0185 | Win count 382
# Epoch 543/999 | Loss 0.0257 | Win count 382
# Epoch 544/999 | Loss 0.0307 | Win count 383
# Epoch 545/999 | Loss 0.0359 | Win count 384
# Epoch 546/999 | Loss 0.0201 | Win count 385
# Epoch 547/999 | Loss 0.0320 | Win count 386
# Epoch 548/999 | Loss 0.0231 | Win count 387
# Epoch 549/999 | Loss 0.0129 | Win count 387
# Epoch 550/999 | Loss 0.0258 | Win count 387
# Epoch 551/999 | Loss 0.0239 | Win count 388
# Epoch 552/999 | Loss 0.0348 | Win count 389
# Epoch 553/999 | Loss 0.0408 | Win count 390
# Epoch 554/999 | Loss 0.0474 | Win count 391
# Epoch 555/999 | Loss 0.0291 | Win count 392
# Epoch 556/999 | Loss 0.0216 | Win count 392
# Epoch 557/999 | Loss 0.0509 | Win count 393
# Epoch 558/999 | Loss 0.0388 | Win count 394
# Epoch 559/999 | Loss 0.0271 | Win count 395
# Epoch 560/999 | Loss 0.0499 | Win count 396
# Epoch 561/999 | Loss 0.0222 | Win count 397
# Epoch 562/999 | Loss 0.0243 | Win count 398
# Epoch 563/999 | Loss 0.0378 | Win count 399
# Epoch 564/999 | Loss 0.0349 | Win count 399
# Epoch 565/999 | Loss 0.0371 | Win count 400
# Epoch 566/999 | Loss 0.0769 | Win count 401
# Epoch 567/999 | Loss 0.0240 | Win count 402
# Epoch 568/999 | Loss 0.0532 | Win count 403
# Epoch 569/999 | Loss 0.0631 | Win count 404
# Epoch 570/999 | Loss 0.0528 | Win count 405
# Epoch 571/999 | Loss 0.0350 | Win count 406
# Epoch 572/999 | Loss 0.0199 | Win count 407
# Epoch 573/999 | Loss 0.0273 | Win count 408
# Epoch 574/999 | Loss 0.0332 | Win count 409
# Epoch 575/999 | Loss 0.0332 | Win count 410
# Epoch 576/999 | Loss 0.0705 | Win count 411
# Epoch 577/999 | Loss 0.0192 | Win count 412
# Epoch 578/999 | Loss 0.0511 | Win count 413
# Epoch 579/999 | Loss 0.0205 | Win count 414
# Epoch 580/999 | Loss 0.0326 | Win count 415
# Epoch 581/999 | Loss 0.0191 | Win count 416
# Epoch 582/999 | Loss 0.0406 | Win count 416
# Epoch 583/999 | Loss 0.0241 | Win count 417
# Epoch 584/999 | Loss 0.0240 | Win count 418
# Epoch 585/999 | Loss 0.0311 | Win count 419
# Epoch 586/999 | Loss 0.0156 | Win count 420
# Epoch 587/999 | Loss 0.0109 | Win count 421
# Epoch 588/999 | Loss 0.0234 | Win count 422
# Epoch 589/999 | Loss 0.0215 | Win count 423
# Epoch 590/999 | Loss 0.0310 | Win count 424
# Epoch 591/999 | Loss 0.0110 | Win count 425
# Epoch 592/999 | Loss 0.0128 | Win count 426
# Epoch 593/999 | Loss 0.0386 | Win count 427
# Epoch 594/999 | Loss 0.0274 | Win count 428
# Epoch 595/999 | Loss 0.0185 | Win count 429
# Epoch 596/999 | Loss 0.0212 | Win count 430
# Epoch 597/999 | Loss 0.0276 | Win count 431
# Epoch 598/999 | Loss 0.0202 | Win count 432
# Epoch 599/999 | Loss 0.0148 | Win count 433
# Epoch 600/999 | Loss 0.0282 | Win count 434
# Epoch 601/999 | Loss 0.0203 | Win count 435
# Epoch 602/999 | Loss 0.0472 | Win count 436
# Epoch 603/999 | Loss 0.0167 | Win count 437
# Epoch 604/999 | Loss 0.0256 | Win count 438
# Epoch 605/999 | Loss 0.0202 | Win count 439
# Epoch 606/999 | Loss 0.0166 | Win count 440
# Epoch 607/999 | Loss 0.0145 | Win count 441
# Epoch 608/999 | Loss 0.0336 | Win count 442
# Epoch 609/999 | Loss 0.0241 | Win count 443
# Epoch 610/999 | Loss 0.0199 | Win count 444
# Epoch 611/999 | Loss 0.0168 | Win count 445
# Epoch 612/999 | Loss 0.0122 | Win count 446
# Epoch 613/999 | Loss 0.0107 | Win count 447
# Epoch 614/999 | Loss 0.0073 | Win count 448
# Epoch 615/999 | Loss 0.0264 | Win count 449
# Epoch 616/999 | Loss 0.0163 | Win count 450
# Epoch 617/999 | Loss 0.0224 | Win count 451
# Epoch 618/999 | Loss 0.0165 | Win count 452
# Epoch 619/999 | Loss 0.0216 | Win count 453
# Epoch 620/999 | Loss 0.0067 | Win count 454
# Epoch 621/999 | Loss 0.0104 | Win count 454
# Epoch 622/999 | Loss 0.0175 | Win count 455
# Epoch 623/999 | Loss 0.0145 | Win count 456
# Epoch 624/999 | Loss 0.0183 | Win count 457
# Epoch 625/999 | Loss 0.0188 | Win count 458
# Epoch 626/999 | Loss 0.0144 | Win count 459
# Epoch 627/999 | Loss 0.0166 | Win count 460
# Epoch 628/999 | Loss 0.0130 | Win count 461
# Epoch 629/999 | Loss 0.0182 | Win count 462
# Epoch 630/999 | Loss 0.0170 | Win count 463
# Epoch 631/999 | Loss 0.0158 | Win count 464
# Epoch 632/999 | Loss 0.0154 | Win count 465
# Epoch 633/999 | Loss 0.0143 | Win count 465
# Epoch 634/999 | Loss 0.0336 | Win count 466
# Epoch 635/999 | Loss 0.0216 | Win count 467
# Epoch 636/999 | Loss 0.0131 | Win count 468
# Epoch 637/999 | Loss 0.0161 | Win count 469
# Epoch 638/999 | Loss 0.0249 | Win count 470
# Epoch 639/999 | Loss 0.0172 | Win count 471
# Epoch 640/999 | Loss 0.0119 | Win count 472
# Epoch 641/999 | Loss 0.0098 | Win count 473
# Epoch 642/999 | Loss 0.0309 | Win count 474
# Epoch 643/999 | Loss 0.0079 | Win count 475
# Epoch 644/999 | Loss 0.0115 | Win count 476
# Epoch 645/999 | Loss 0.0146 | Win count 476
# Epoch 646/999 | Loss 0.0656 | Win count 476
# Epoch 647/999 | Loss 0.0237 | Win count 477
# Epoch 648/999 | Loss 0.0585 | Win count 478
# Epoch 649/999 | Loss 0.0212 | Win count 479
# Epoch 650/999 | Loss 0.0211 | Win count 480
# Epoch 651/999 | Loss 0.0564 | Win count 481
# Epoch 652/999 | Loss 0.0647 | Win count 482
# Epoch 653/999 | Loss 0.0245 | Win count 483
# Epoch 654/999 | Loss 0.0390 | Win count 484
# Epoch 655/999 | Loss 0.0264 | Win count 485
# Epoch 656/999 | Loss 0.0398 | Win count 486
# Epoch 657/999 | Loss 0.0251 | Win count 487
# Epoch 658/999 | Loss 0.0362 | Win count 488
# Epoch 659/999 | Loss 0.0388 | Win count 489
# Epoch 660/999 | Loss 0.0141 | Win count 490
# Epoch 661/999 | Loss 0.0218 | Win count 491
# Epoch 662/999 | Loss 0.0109 | Win count 491
# Epoch 663/999 | Loss 0.0346 | Win count 492
# Epoch 664/999 | Loss 0.0231 | Win count 493
# Epoch 665/999 | Loss 0.0170 | Win count 494
# Epoch 666/999 | Loss 0.0197 | Win count 495
# Epoch 667/999 | Loss 0.0188 | Win count 496
# Epoch 668/999 | Loss 0.0170 | Win count 497
# Epoch 669/999 | Loss 0.0233 | Win count 498
# Epoch 670/999 | Loss 0.0109 | Win count 499
# Epoch 671/999 | Loss 0.0075 | Win count 500
# Epoch 672/999 | Loss 0.0078 | Win count 500
# Epoch 673/999 | Loss 0.0305 | Win count 501
# Epoch 674/999 | Loss 0.0233 | Win count 502
# Epoch 675/999 | Loss 0.0269 | Win count 503
# Epoch 676/999 | Loss 0.0141 | Win count 504
# Epoch 677/999 | Loss 0.0229 | Win count 505
# Epoch 678/999 | Loss 0.0223 | Win count 506
# Epoch 679/999 | Loss 0.0204 | Win count 507
# Epoch 680/999 | Loss 0.0332 | Win count 508
# Epoch 681/999 | Loss 0.0381 | Win count 509
# Epoch 682/999 | Loss 0.0200 | Win count 510
# Epoch 683/999 | Loss 0.0210 | Win count 511
# Epoch 684/999 | Loss 0.0238 | Win count 512
# Epoch 685/999 | Loss 0.0205 | Win count 513
# Epoch 686/999 | Loss 0.0165 | Win count 514
# Epoch 687/999 | Loss 0.0162 | Win count 515
# Epoch 688/999 | Loss 0.0153 | Win count 516
# Epoch 689/999 | Loss 0.0170 | Win count 517
# Epoch 690/999 | Loss 0.0129 | Win count 518
# Epoch 691/999 | Loss 0.0168 | Win count 519
# Epoch 692/999 | Loss 0.0225 | Win count 520
# Epoch 693/999 | Loss 0.0147 | Win count 521
# Epoch 694/999 | Loss 0.0054 | Win count 522
# Epoch 695/999 | Loss 0.0105 | Win count 523
# Epoch 696/999 | Loss 0.0168 | Win count 524
# Epoch 697/999 | Loss 0.0172 | Win count 525
# Epoch 698/999 | Loss 0.0135 | Win count 526
# Epoch 699/999 | Loss 0.0108 | Win count 527
# Epoch 700/999 | Loss 0.0149 | Win count 528
# Epoch 701/999 | Loss 0.0162 | Win count 529
# Epoch 702/999 | Loss 0.0128 | Win count 530
# Epoch 703/999 | Loss 0.0163 | Win count 530
# Epoch 704/999 | Loss 0.0135 | Win count 531
# Epoch 705/999 | Loss 0.0162 | Win count 532
# Epoch 706/999 | Loss 0.0142 | Win count 533
# Epoch 707/999 | Loss 0.0145 | Win count 534
# Epoch 708/999 | Loss 0.0176 | Win count 535
# Epoch 709/999 | Loss 0.0127 | Win count 536
# Epoch 710/999 | Loss 0.0158 | Win count 537
# Epoch 711/999 | Loss 0.0181 | Win count 538
# Epoch 712/999 | Loss 0.0258 | Win count 539
# Epoch 713/999 | Loss 0.0152 | Win count 540
# Epoch 714/999 | Loss 0.0240 | Win count 541
# Epoch 715/999 | Loss 0.0222 | Win count 542
# Epoch 716/999 | Loss 0.0147 | Win count 543
# Epoch 717/999 | Loss 0.0229 | Win count 544
# Epoch 718/999 | Loss 0.0111 | Win count 545
# Epoch 719/999 | Loss 0.0196 | Win count 546
# Epoch 720/999 | Loss 0.0273 | Win count 547
# Epoch 721/999 | Loss 0.0164 | Win count 547
# Epoch 722/999 | Loss 0.0238 | Win count 548
# Epoch 723/999 | Loss 0.0325 | Win count 549
# Epoch 724/999 | Loss 0.0177 | Win count 549
# Epoch 725/999 | Loss 0.0201 | Win count 550
# Epoch 726/999 | Loss 0.0158 | Win count 551
# Epoch 727/999 | Loss 0.0236 | Win count 552
# Epoch 728/999 | Loss 0.0194 | Win count 553
# Epoch 729/999 | Loss 0.0140 | Win count 554
# Epoch 730/999 | Loss 0.0147 | Win count 555
# Epoch 731/999 | Loss 0.0191 | Win count 556
# Epoch 732/999 | Loss 0.0141 | Win count 557
# Epoch 733/999 | Loss 0.0123 | Win count 558
# Epoch 734/999 | Loss 0.0157 | Win count 559
# Epoch 735/999 | Loss 0.0168 | Win count 560
# Epoch 736/999 | Loss 0.0185 | Win count 561
# Epoch 737/999 | Loss 0.0183 | Win count 562
# Epoch 738/999 | Loss 0.0130 | Win count 563
# Epoch 739/999 | Loss 0.0109 | Win count 564
# Epoch 740/999 | Loss 0.0160 | Win count 565
# Epoch 741/999 | Loss 0.0162 | Win count 566
# Epoch 742/999 | Loss 0.0110 | Win count 567
# Epoch 743/999 | Loss 0.0149 | Win count 568
# Epoch 744/999 | Loss 0.0123 | Win count 569
# Epoch 745/999 | Loss 0.0098 | Win count 570
# Epoch 746/999 | Loss 0.0153 | Win count 571
# Epoch 747/999 | Loss 0.0096 | Win count 572
# Epoch 748/999 | Loss 0.0078 | Win count 573
# Epoch 749/999 | Loss 0.0060 | Win count 574
# Epoch 750/999 | Loss 0.0071 | Win count 575
# Epoch 751/999 | Loss 0.0093 | Win count 576
# Epoch 752/999 | Loss 0.0127 | Win count 577
# Epoch 753/999 | Loss 0.0091 | Win count 578
# Epoch 754/999 | Loss 0.0138 | Win count 579
# Epoch 755/999 | Loss 0.0076 | Win count 580
# Epoch 756/999 | Loss 0.0083 | Win count 581
# Epoch 757/999 | Loss 0.0081 | Win count 582
# Epoch 758/999 | Loss 0.0096 | Win count 583
# Epoch 759/999 | Loss 0.0063 | Win count 584
# Epoch 760/999 | Loss 0.0087 | Win count 585
# Epoch 761/999 | Loss 0.0055 | Win count 586
# Epoch 762/999 | Loss 0.0116 | Win count 586
# Epoch 763/999 | Loss 0.0087 | Win count 587
# Epoch 764/999 | Loss 0.0110 | Win count 588
# Epoch 765/999 | Loss 0.0168 | Win count 588
# Epoch 766/999 | Loss 0.0158 | Win count 589
# Epoch 767/999 | Loss 0.0108 | Win count 589
# Epoch 768/999 | Loss 0.0150 | Win count 590
# Epoch 769/999 | Loss 0.0135 | Win count 591
# Epoch 770/999 | Loss 0.0400 | Win count 592
# Epoch 771/999 | Loss 0.0368 | Win count 593
# Epoch 772/999 | Loss 0.0414 | Win count 594
# Epoch 773/999 | Loss 0.0234 | Win count 595
# Epoch 774/999 | Loss 0.0218 | Win count 595
# Epoch 775/999 | Loss 0.0397 | Win count 596
# Epoch 776/999 | Loss 0.0361 | Win count 597
# Epoch 777/999 | Loss 0.0163 | Win count 598
# Epoch 778/999 | Loss 0.0305 | Win count 599
# Epoch 779/999 | Loss 0.0214 | Win count 600
# Epoch 780/999 | Loss 0.0201 | Win count 601
# Epoch 781/999 | Loss 0.0186 | Win count 602
# Epoch 782/999 | Loss 0.0202 | Win count 603
# Epoch 783/999 | Loss 0.0079 | Win count 604
# Epoch 784/999 | Loss 0.0163 | Win count 605
# Epoch 785/999 | Loss 0.0090 | Win count 606
# Epoch 786/999 | Loss 0.0153 | Win count 607
# Epoch 787/999 | Loss 0.0135 | Win count 608
# Epoch 788/999 | Loss 0.0071 | Win count 609
# Epoch 789/999 | Loss 0.0125 | Win count 610
# Epoch 790/999 | Loss 0.0146 | Win count 611
# Epoch 791/999 | Loss 0.0051 | Win count 612
# Epoch 792/999 | Loss 0.0065 | Win count 613
# Epoch 793/999 | Loss 0.0065 | Win count 614
# Epoch 794/999 | Loss 0.0068 | Win count 615
# Epoch 795/999 | Loss 0.0100 | Win count 616
# Epoch 796/999 | Loss 0.0075 | Win count 617
# Epoch 797/999 | Loss 0.0048 | Win count 618
# Epoch 798/999 | Loss 0.0075 | Win count 619
# Epoch 799/999 | Loss 0.0068 | Win count 620
# Epoch 800/999 | Loss 0.0115 | Win count 621
# Epoch 801/999 | Loss 0.0039 | Win count 622
# Epoch 802/999 | Loss 0.0062 | Win count 623
# Epoch 803/999 | Loss 0.0098 | Win count 624
# Epoch 804/999 | Loss 0.0092 | Win count 625
# Epoch 805/999 | Loss 0.0094 | Win count 626
# Epoch 806/999 | Loss 0.0079 | Win count 627
# Epoch 807/999 | Loss 0.0061 | Win count 628
# Epoch 808/999 | Loss 0.0080 | Win count 629
# Epoch 809/999 | Loss 0.0055 | Win count 630
# Epoch 810/999 | Loss 0.0060 | Win count 631
# Epoch 811/999 | Loss 0.0071 | Win count 632
# Epoch 812/999 | Loss 0.0057 | Win count 633
# Epoch 813/999 | Loss 0.0084 | Win count 634
# Epoch 814/999 | Loss 0.0072 | Win count 635
# Epoch 815/999 | Loss 0.0068 | Win count 636
# Epoch 816/999 | Loss 0.0079 | Win count 637
# Epoch 817/999 | Loss 0.0045 | Win count 638
# Epoch 818/999 | Loss 0.0067 | Win count 639
# Epoch 819/999 | Loss 0.0048 | Win count 640
# Epoch 820/999 | Loss 0.0036 | Win count 641
# Epoch 821/999 | Loss 0.0049 | Win count 642
# Epoch 822/999 | Loss 0.0022 | Win count 643
# Epoch 823/999 | Loss 0.0032 | Win count 644
# Epoch 824/999 | Loss 0.0045 | Win count 645
# Epoch 825/999 | Loss 0.0031 | Win count 646
# Epoch 826/999 | Loss 0.0034 | Win count 647
# Epoch 827/999 | Loss 0.0027 | Win count 648
# Epoch 828/999 | Loss 0.0039 | Win count 649
# Epoch 829/999 | Loss 0.0034 | Win count 650
# Epoch 830/999 | Loss 0.0027 | Win count 651
# Epoch 831/999 | Loss 0.0029 | Win count 652
# Epoch 832/999 | Loss 0.0019 | Win count 653
# Epoch 833/999 | Loss 0.0019 | Win count 654
# Epoch 834/999 | Loss 0.0019 | Win count 655
# Epoch 835/999 | Loss 0.0018 | Win count 656
# Epoch 836/999 | Loss 0.0020 | Win count 657
# Epoch 837/999 | Loss 0.0025 | Win count 658
# Epoch 838/999 | Loss 0.0053 | Win count 658
# Epoch 839/999 | Loss 0.0031 | Win count 659
# Epoch 840/999 | Loss 0.0042 | Win count 660
# Epoch 841/999 | Loss 0.0035 | Win count 661
# Epoch 842/999 | Loss 0.0040 | Win count 662
# Epoch 843/999 | Loss 0.0125 | Win count 663
# Epoch 844/999 | Loss 0.0109 | Win count 664
# Epoch 845/999 | Loss 0.0134 | Win count 665
# Epoch 846/999 | Loss 0.0041 | Win count 666
# Epoch 847/999 | Loss 0.0056 | Win count 667
# Epoch 848/999 | Loss 0.0084 | Win count 668
# Epoch 849/999 | Loss 0.0119 | Win count 669
# Epoch 850/999 | Loss 0.0053 | Win count 670
# Epoch 851/999 | Loss 0.0051 | Win count 671
# Epoch 852/999 | Loss 0.0044 | Win count 672
# Epoch 853/999 | Loss 0.0039 | Win count 673
# Epoch 854/999 | Loss 0.0079 | Win count 674
# Epoch 855/999 | Loss 0.0138 | Win count 675
# Epoch 856/999 | Loss 0.0078 | Win count 676
# Epoch 857/999 | Loss 0.0128 | Win count 677
# Epoch 858/999 | Loss 0.0172 | Win count 678
# Epoch 859/999 | Loss 0.0123 | Win count 679
# Epoch 860/999 | Loss 0.0117 | Win count 680
# Epoch 861/999 | Loss 0.0100 | Win count 681
# Epoch 862/999 | Loss 0.0152 | Win count 682
# Epoch 863/999 | Loss 0.0108 | Win count 683
# Epoch 864/999 | Loss 0.0136 | Win count 684
# Epoch 865/999 | Loss 0.0114 | Win count 685
# Epoch 866/999 | Loss 0.0083 | Win count 686
# Epoch 867/999 | Loss 0.0433 | Win count 687
# Epoch 868/999 | Loss 0.0291 | Win count 688
# Epoch 869/999 | Loss 0.0358 | Win count 689
# Epoch 870/999 | Loss 0.0227 | Win count 690
# Epoch 871/999 | Loss 0.0113 | Win count 691
# Epoch 872/999 | Loss 0.0240 | Win count 692
# Epoch 873/999 | Loss 0.0257 | Win count 693
# Epoch 874/999 | Loss 0.0145 | Win count 694
# Epoch 875/999 | Loss 0.0226 | Win count 695
# Epoch 876/999 | Loss 0.0200 | Win count 695
# Epoch 877/999 | Loss 0.0144 | Win count 696
# Epoch 878/999 | Loss 0.0192 | Win count 697
# Epoch 879/999 | Loss 0.0164 | Win count 698
# Epoch 880/999 | Loss 0.0185 | Win count 699
# Epoch 881/999 | Loss 0.0152 | Win count 700
# Epoch 882/999 | Loss 0.0259 | Win count 701
# Epoch 883/999 | Loss 0.0113 | Win count 702
# Epoch 884/999 | Loss 0.0186 | Win count 703
# Epoch 885/999 | Loss 0.0224 | Win count 704
# Epoch 886/999 | Loss 0.0193 | Win count 705
# Epoch 887/999 | Loss 0.0165 | Win count 706
# Epoch 888/999 | Loss 0.0234 | Win count 707
# Epoch 889/999 | Loss 0.0119 | Win count 708
# Epoch 890/999 | Loss 0.0111 | Win count 709
# Epoch 891/999 | Loss 0.0129 | Win count 710
# Epoch 892/999 | Loss 0.0146 | Win count 711
# Epoch 893/999 | Loss 0.0157 | Win count 712
# Epoch 894/999 | Loss 0.0123 | Win count 713
# Epoch 895/999 | Loss 0.0128 | Win count 714
# Epoch 896/999 | Loss 0.0125 | Win count 715
# Epoch 897/999 | Loss 0.0138 | Win count 716
# Epoch 898/999 | Loss 0.0112 | Win count 717
# Epoch 899/999 | Loss 0.0178 | Win count 717
# Epoch 900/999 | Loss 0.0145 | Win count 718
# Epoch 901/999 | Loss 0.0102 | Win count 719
# Epoch 902/999 | Loss 0.0127 | Win count 720
# Epoch 903/999 | Loss 0.0165 | Win count 721
# Epoch 904/999 | Loss 0.0168 | Win count 722
# Epoch 905/999 | Loss 0.0130 | Win count 723
# Epoch 906/999 | Loss 0.0180 | Win count 724
# Epoch 907/999 | Loss 0.0137 | Win count 725
# Epoch 908/999 | Loss 0.0111 | Win count 726
# Epoch 909/999 | Loss 0.0091 | Win count 727
# Epoch 910/999 | Loss 0.0082 | Win count 728
# Epoch 911/999 | Loss 0.0116 | Win count 729
# Epoch 912/999 | Loss 0.0073 | Win count 730
# Epoch 913/999 | Loss 0.0072 | Win count 731
# Epoch 914/999 | Loss 0.0075 | Win count 732
# Epoch 915/999 | Loss 0.0084 | Win count 733
# Epoch 916/999 | Loss 0.0089 | Win count 734
# Epoch 917/999 | Loss 0.0087 | Win count 735
# Epoch 918/999 | Loss 0.0082 | Win count 736
# Epoch 919/999 | Loss 0.0069 | Win count 737
# Epoch 920/999 | Loss 0.0074 | Win count 738
# Epoch 921/999 | Loss 0.0095 | Win count 739
# Epoch 922/999 | Loss 0.0077 | Win count 740
# Epoch 923/999 | Loss 0.0062 | Win count 741
# Epoch 924/999 | Loss 0.0070 | Win count 742
# Epoch 925/999 | Loss 0.0080 | Win count 742
# Epoch 926/999 | Loss 0.0142 | Win count 743
# Epoch 927/999 | Loss 0.0096 | Win count 744
# Epoch 928/999 | Loss 0.0203 | Win count 744
# Epoch 929/999 | Loss 0.0120 | Win count 745
# Epoch 930/999 | Loss 0.0240 | Win count 746
# Epoch 931/999 | Loss 0.0100 | Win count 747
# Epoch 932/999 | Loss 0.0266 | Win count 748
# Epoch 933/999 | Loss 0.0439 | Win count 749
# Epoch 934/999 | Loss 0.0078 | Win count 750
# Epoch 935/999 | Loss 0.0226 | Win count 751
# Epoch 936/999 | Loss 0.0225 | Win count 752
# Epoch 937/999 | Loss 0.0165 | Win count 753
# Epoch 938/999 | Loss 0.0278 | Win count 754
# Epoch 939/999 | Loss 0.0108 | Win count 755
# Epoch 940/999 | Loss 0.0095 | Win count 756
# Epoch 941/999 | Loss 0.0064 | Win count 757
# Epoch 942/999 | Loss 0.0192 | Win count 758
# Epoch 943/999 | Loss 0.0166 | Win count 759
# Epoch 944/999 | Loss 0.0197 | Win count 760
# Epoch 945/999 | Loss 0.0166 | Win count 761
# Epoch 946/999 | Loss 0.0085 | Win count 762
# Epoch 947/999 | Loss 0.0116 | Win count 762
# Epoch 948/999 | Loss 0.0071 | Win count 763
# Epoch 949/999 | Loss 0.0223 | Win count 764
# Epoch 950/999 | Loss 0.0149 | Win count 765
# Epoch 951/999 | Loss 0.0106 | Win count 766
# Epoch 952/999 | Loss 0.0164 | Win count 767
# Epoch 953/999 | Loss 0.0105 | Win count 768
# Epoch 954/999 | Loss 0.0203 | Win count 769
# Epoch 955/999 | Loss 0.0123 | Win count 770
# Epoch 956/999 | Loss 0.0151 | Win count 771
# Epoch 957/999 | Loss 0.0105 | Win count 772
# Epoch 958/999 | Loss 0.0126 | Win count 773
# Epoch 959/999 | Loss 0.0154 | Win count 773
# Epoch 960/999 | Loss 0.0279 | Win count 774
# Epoch 961/999 | Loss 0.0104 | Win count 775
# Epoch 962/999 | Loss 0.0122 | Win count 776
# Epoch 963/999 | Loss 0.0200 | Win count 777
# Epoch 964/999 | Loss 0.0087 | Win count 778
# Epoch 965/999 | Loss 0.0142 | Win count 779
# Epoch 966/999 | Loss 0.0213 | Win count 780
# Epoch 967/999 | Loss 0.0144 | Win count 781
# Epoch 968/999 | Loss 0.0075 | Win count 782
# Epoch 969/999 | Loss 0.0171 | Win count 783
# Epoch 970/999 | Loss 0.0122 | Win count 784
# Epoch 971/999 | Loss 0.0108 | Win count 785
# Epoch 972/999 | Loss 0.0098 | Win count 786
# Epoch 973/999 | Loss 0.0209 | Win count 787
# Epoch 974/999 | Loss 0.0194 | Win count 788
# Epoch 975/999 | Loss 0.0097 | Win count 788
# Epoch 976/999 | Loss 0.0184 | Win count 789
# Epoch 977/999 | Loss 0.0160 | Win count 790
# Epoch 978/999 | Loss 0.0130 | Win count 791
# Epoch 979/999 | Loss 0.0136 | Win count 792
# Epoch 980/999 | Loss 0.0078 | Win count 793
# Epoch 981/999 | Loss 0.0119 | Win count 794
# Epoch 982/999 | Loss 0.0102 | Win count 795
# Epoch 983/999 | Loss 0.0138 | Win count 796
# Epoch 984/999 | Loss 0.0131 | Win count 796
# Epoch 985/999 | Loss 0.0128 | Win count 797
# Epoch 986/999 | Loss 0.0121 | Win count 798
# Epoch 987/999 | Loss 0.0130 | Win count 799
# Epoch 988/999 | Loss 0.0116 | Win count 800
# Epoch 989/999 | Loss 0.0132 | Win count 801
# Epoch 990/999 | Loss 0.0084 | Win count 802
# Epoch 991/999 | Loss 0.0071 | Win count 803
# Epoch 992/999 | Loss 0.0059 | Win count 804
# Epoch 993/999 | Loss 0.0144 | Win count 805
# Epoch 994/999 | Loss 0.0095 | Win count 806
# Epoch 995/999 | Loss 0.0168 | Win count 807
# Epoch 996/999 | Loss 0.0110 | Win count 808
# Epoch 997/999 | Loss 0.0122 | Win count 809
# Epoch 998/999 | Loss 0.0116 | Win count 810
# Epoch 999/999 | Loss 0.0118 | Win count 811

# %%
# %matplotlib inline
import json
import matplotlib.pyplot as plt
import numpy as np
from keras.models import model_from_json
#from qlearn import Catch


if __name__ == "__main__":
    # Make sure this grid size matches the value used fro training
    grid_size = 10

    with open("model.json", "r") as jfile:
        model = model_from_json(json.load(jfile))
    model.load_weights("model.h5")
    model.compile("sgd", "mse")

    # Define environment, game
    env = Catch(grid_size)
    c = 0
    for e in range(10):
        loss = 0.
        env.reset()
        game_over = False
        # get initial input
        input_t = env.observe()

        plt.imshow(input_t.reshape((grid_size,)*2),
                   interpolation='none', cmap='gray')
        plt.savefig("%03d.png" % c)
        c += 1
        while not game_over:
            input_tm1 = input_t

            # get next action
            q = model.predict(input_tm1)
            action = np.argmax(q[0])

            # apply action, get rewards and new state
            input_t, reward, game_over = env.act(action)

            plt.imshow(input_t.reshape((grid_size,)*2),
                       interpolation='none', cmap='gray')
            #plt.savefig("%03d.png" % c)
            c += 1

# %%
# !ls
# Out:
# model.json  sample_data
