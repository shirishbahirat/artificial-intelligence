# %% [markdown]
# <a href="https://colab.research.google.com/github/shirishbahirat/artificial-intelligence/blob/master/linear_regression_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''A simple MLP in Keras implementing linear regression.
'''

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

# numpy package
import numpy as np

# keras modules
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import plot_model

# generate x data
x = np.arange(-1,1,0.2)
x = np.reshape(x, [-1,1])

# generate y data
y = 2 * x + 3

# True if noise is added to y
is_noisy = True

# add noise if enabled
if is_noisy:
    noise = np.random.uniform(-0.1, 0.1, x.shape)
    x = x + noise

# deep learning method
# build 2-layer MLP network 
model = Sequential()
# 1st MLP has 8 units (perceptron), input is 1-dim
model.add(Dense(units=8, input_dim=1))
# 2nd MLP has 1 unit, output is 1-dim
model.add(Dense(units=1))
# print summary to double check the network
model.summary()
# create a nice image of the network model
plot_model(model, to_file='linear-model.png', show_shapes=True)
# indicate the loss function and use stochastic gradient descent
# (sgd) as optimizer
model.compile(loss='mse', optimizer='sgd')
# feed the network with complete dataset (1 epoch) 100 times
# batch size of sgd is 4
model.fit(x, y, epochs=100, batch_size=4)
# simple validation by predicting the output based on x
ypred = model.predict(x)

# linear algebra method
ones = np.ones(x.shape)
# A is the concat of x and 1s
A = np.concatenate([x,ones], axis=1)
# compute k using using pseudo-inverse
k = np.matmul(np.linalg.pinv(A), y) 
print("k (Linear Algebra Method):")
print(k)
# predict the output using linear algebra solution
yla = np.matmul(A, k)

# print ground truth, linear algebra, MLP solutions
outputs = np.concatenate([y, yla, ypred], axis=1)
print("Ground Truth, Linear Alg Prediction, MLP Prediction")
print(outputs)

# Uncomment to see the output for a new input data 
# that is not part of the training data.
# x = np.array([2])
# ypred = model.predict(x)
# print(ypred)
# Out:
# Using TensorFlow backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 8)                 16
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 25
# Trainable params: 25
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 10/10 [==============================] - 1s 70ms/step - loss: 9.5753
# Epoch 2/100
# 10/10 [==============================] - 0s 1ms/step - loss: 7.4109
# Epoch 3/100
# 10/10 [==============================] - 0s 1ms/step - loss: 5.8822
# Epoch 4/100
# 10/10 [==============================] - 0s 1ms/step - loss: 4.7433
# Epoch 5/100
# 10/10 [==============================] - 0s 1ms/step - loss: 3.6986
# Epoch 6/100
# 10/10 [==============================] - 0s 1ms/step - loss: 2.9527
# Epoch 7/100
# 10/10 [==============================] - 0s 1ms/step - loss: 2.5008
# Epoch 8/100
# 10/10 [==============================] - 0s 1ms/step - loss: 2.1609
# Epoch 9/100
# 10/10 [==============================] - 0s 2ms/step - loss: 1.8589
# Epoch 10/100
# 10/10 [==============================] - 0s 1ms/step - loss: 1.5028
# Epoch 11/100
# 10/10 [==============================] - 0s 1ms/step - loss: 1.2853
# Epoch 12/100
# 10/10 [==============================] - 0s 1ms/step - loss: 1.0955
# Epoch 13/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.9650
# Epoch 14/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7946
# Epoch 15/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.7025
# Epoch 16/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6000
# Epoch 17/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.5029
# Epoch 18/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4317
# Epoch 19/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3816
# Epoch 20/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3027
# Epoch 21/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2717
# Epoch 22/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2171
# Epoch 23/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1871
# Epoch 24/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1645
# Epoch 25/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1357
# Epoch 26/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1157
# Epoch 27/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0989
# Epoch 28/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0859
# Epoch 29/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0738
# Epoch 30/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0644
# Epoch 31/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0563
# Epoch 32/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0465
# Epoch 33/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0425
# Epoch 34/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0387
# Epoch 35/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0329
# Epoch 36/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0289
# Epoch 37/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0271
# Epoch 38/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0243
# Epoch 39/100
# 10/10 [==============================] - 0s 996us/step - loss: 0.0211
# Epoch 40/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0198
# Epoch 41/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0192
# Epoch 42/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0184
# Epoch 43/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0178
# Epoch 44/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0174
# Epoch 45/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0164
# Epoch 46/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0160
# Epoch 47/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0160
# Epoch 48/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0152
# Epoch 49/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0152
# Epoch 50/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0149
# Epoch 51/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0155
# Epoch 52/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0148
# Epoch 53/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0144
# Epoch 54/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0141
# Epoch 55/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0145
# Epoch 56/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0142
# Epoch 57/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0140
# Epoch 58/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0141
# Epoch 59/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0138
# Epoch 60/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0139
# Epoch 61/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0142
# Epoch 62/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0138
# Epoch 63/100
# 10/10 [==============================] - 0s 884us/step - loss: 0.0138
# Epoch 64/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0141
# Epoch 65/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0140
# Epoch 66/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0140
# Epoch 67/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0144
# Epoch 68/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0139
# Epoch 69/100
# 10/10 [==============================] - 0s 972us/step - loss: 0.0143
# Epoch 70/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0140
# Epoch 71/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0144
# Epoch 72/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0143
# Epoch 73/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0142
# Epoch 74/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0145
# Epoch 75/100
# 10/10 [==============================] - 0s 980us/step - loss: 0.0139
# Epoch 76/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0140
# Epoch 77/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0140
# Epoch 78/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0143
# Epoch 79/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0140
# Epoch 80/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0145
# Epoch 81/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0142
# Epoch 82/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0140
# Epoch 83/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0140
# Epoch 84/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0140
# Epoch 85/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0143
# Epoch 86/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0143
# Epoch 87/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0138
# Epoch 88/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0140
# Epoch 89/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0145
# Epoch 90/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0147
# Epoch 91/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0145
# Epoch 92/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0145
# Epoch 93/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0147
# Epoch 94/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0145
# Epoch 95/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0143
# Epoch 96/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0143
# Epoch 97/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0140
# Epoch 98/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0141
# Epoch 99/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0139
# Epoch 100/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0138
# k (Linear Algebra Method):
# [[1.95289148]
#  [3.03605658]]
# Ground Truth, Linear Alg Prediction, MLP Prediction
# [[1.         1.18539346 1.19046116]
#  [1.4        1.34649741 1.35099924]
#  [1.8        1.73154911 1.7346983 ]
#  [2.2        2.32918231 2.33023214]
#  [2.6        2.47531922 2.47585535]
#  [3.         2.87473508 2.87386799]
#  [3.4        3.39358255 3.39089251]
#  [3.8        3.68337582 3.67966795]
#  [4.2        4.38247187 4.37630844]
#  [4.6        4.59789317 4.5909729 ]]
